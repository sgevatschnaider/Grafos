# %% [markdown]
# <a href="https://colab.research.google.com/github/sgevatschnaider/Grafos/blob/main/notebooks/BIG_DATA_CLASE_11_Dijkstra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML

# Contenido HTML
html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Material Elaborado por Sergio Gevatschnaider</title>
    <style>
        /* Estilos básicos */
        body {
            font-family: 'Georgia', serif;
            line-height: 1.8;
            margin: 20px;
            padding: 20px;
            background-color: #f9f9f9;
            background-image: url('https://www.transparenttextures.com/patterns/light-paper-fibers.png');
            background-size: cover;
            background-attachment: fixed;
            background-blend-mode: lighten;
        }
        /* Barra de navegación fija */
        .navbar {
            background-color: #0066cc;
            color: white;
            padding: 10px 15px;
            text-align: center;
            font-size: 1.2em;
            position: fixed;
            width: 100%;
            top: 0;
            left: 0;
            z-index: 1000;
        }
        /* Espaciado para evitar superposición con la barra */
        body {
            padding-top: 60px;
        }
        /* Estilos de encabezados */
        h1 {
            color: #333;
            text-align: center;
            font-size: 2.5em;
            margin-bottom: 20px;
            font-family: 'Arial', sans-serif;
        }
        h2 {
            color: #0066cc;
            font-size: 2em;
            margin-top: 20px;
        }
        h3 {
            color: #333;
            font-size: 1.5em;
            margin-top: 15px;
            margin-bottom: 10px;
        }
        p {
            font-size: 1.2em;
            margin-bottom: 15px;
        }
        /* Estilos de lista */
        ul {
            list-style-type: none;
            margin-left: 20px;
            margin-bottom: 20px;
        }
        li {
            font-size: 1.1em;
            margin-bottom: 10px;
            color: #333;
            position: relative;
        }
        li::before {
            content: "🔹";
            color: #0066cc;
            font-weight: bold;
            margin-right: 8px;
            position: absolute;
            left: -20px;
        }
        /* Botón de descarga */
        .download-link {
            background-color: #ff5722;
            color: white;
            padding: 12px 20px;
            font-size: 1.1em;
            display: inline-block;
            border-radius: 8px;
            transition: background-color 0.3s ease;
            box-shadow: 0px 4px 6px rgba(0, 0, 0, 0.1);
        }
        .download-link:hover {
            background-color: #e64a19;
            box-shadow: 0px 6px 10px rgba(0, 0, 0, 0.15);
        }
        /* Divider */
        .divider {
            height: 2px;
            background-color: #e0e0e0;
            margin: 30px 0;
            border-radius: 4px;
        }
        /* Estilos de tarjeta */
        .card {
            background-color: #ffffff;
            border-radius: 8px;
            box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1);
            padding: 20px;
            margin-bottom: 20px;
        }
    </style>
</head>
<body>
    <div class="navbar">Material de Big Data - Universidad de Palermo</div>

    <h1>Material Elaborado por Sergio Gevatschnaider</h1>
    <p>Clase de Big Data de la Universidad de Palermo</p>
    <p>Basado en el libro <em>Introduction to Graph Theory: A Short Course in Graph Theory</em> por Jacques Verstraete</p>
    <p>El libro se puede descargar en este enlace:</p>
    <p><a href="https://cseweb.ucsd.edu/~dakane/Math154/154-textbook.pdf" target="_blank" class="download-link">Descargar libro</a></p>

    <div class="divider"></div>

    <div class="card">
        <h2>Índice de la Clase: Algoritmos de Caminos Mínimos y el Algoritmo de Dijkstra</h2>
        <ul>
            <li>Introducción a Grafos Dirigidos
                <ul>
                    <li>Definición de grafo dirigido</li>
                    <li>Representación de grafos: nodos y aristas</li>
                    <li>Ejemplos de grafos dirigidos en el mundo real</li>
                </ul>
            </li>
            <li>Concepto de Árbol en Teoría de Grafos
                <ul>
                    <li>Definición de árbol en grafos (acíclico y conexo)</li>
                    <li>Árboles de expansión en grafos y su relación con los caminos</li>
                    <li>Árboles en grafos dirigidos vs. no dirigidos</li>
                </ul>
            </li>
            <li>Planteamiento del Problema: Caminos Mínimos
                <ul>
                    <li>Definición del problema de caminos mínimos</li>
                    <li>Importancia de los pesos en las aristas</li>
                    <li>Aplicaciones del problema de caminos mínimos:
                        <ul>
                            <li>Redes de transporte y navegación</li>
                            <li>Rutas en redes de comunicación y telecomunicaciones</li>
                            <li>Optimización en redes de flujo (suministro de energía, logística)</li>
                        </ul>
                    </li>
                </ul>
            </li>
            <li>El Algoritmo de Dijkstra
                <ul>
                    <li>Introducción a Dijkstra y su objetivo</li>
                    <li>Funcionamiento general del algoritmo:
                        <ul>
                            <li>Expansión del árbol de caminos mínimos</li>
                            <li>Uso de estructuras de datos tipo heap para eficiencia</li>
                            <li>Ventajas y limitaciones de Dijkstra (no admite pesos negativos)</li>
                        </ul>
                    </li>
                </ul>
            </li>
            <li>Implementación Práctica del Algoritmo de Dijkstra
                <ul>
                    <li>Ejemplo de código en Python para resolver el problema de caminos mínimos</li>
                    <li>Explicación paso a paso del código:
                        <ul>
                            <li>Inicialización de distancias</li>
                            <li>Selección del nodo más cercano no procesado</li>
                            <li>Actualización de distancias a los vecinos</li>
                            <li>Prueba y demostración del código con un ejemplo simple</li>
                        </ul>
                    </li>
                </ul>
            </li>
            <li>Referencias
                <ul>
                    <li>Discusión sobre el artículo de investigación adjunto en el PDF:</li>
                    <li>Resumen del avance sobre el algoritmo de Dijkstra y su universalidad</li>
                    <li>Comentario sobre la mejora en la estructura de datos del heap para optimalidad</li>
                    <li>Referencia completa al artículo para quienes quieran profundizar en el tema</li>
                </ul>
            </li>
        </ul>
    </div>
</body>
</html>
"""

# Mostrar el contenido HTML
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Material Elaborado por Sergio Gevatschnaider</title>
#     <style>
#         /* Estilos básicos */
#         body {
#             font-family: 'Georgia', serif;
#             line-height: 1.8;
#             margin: 20px;
#             padding: 20px;
#             background-color: #f9f9f9;
#             background-image: url('https://www.transparenttextures.com/patterns/light-paper-fibers.png');
#             background-size: cover;
#             background-attachment: fixed;
#             background-blend-mode: lighten;
#         }
#         /* Barra de navegación fija */
#         .navbar {
#             background-color: #0066cc;
#             color: white;
#             padding: 10px 15px;
#             text-align: center;
#             font-size: 1.2em;
#             position: fixed;
#             width: 100%;
# ...

# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Referencias sobre Algoritmo de Dijkstra</title>
    <style>
        /* Estilos básicos */
        body {
            font-family: 'Georgia', serif;
            line-height: 1.8;
            margin: 20px;
            padding: 20px;
            background-color: #f9f9f9;
        }
        .navbar {
            background-color: #0066cc;
            color: white;
            padding: 10px 15px;
            text-align: center;
            font-size: 1.2em;
            position: fixed;
            width: 100%;
            top: 0;
            left: 0;
            z-index: 1000;
        }
        .navbar a {
            color: white;
            text-decoration: none;
            padding: 0 10px;
            cursor: pointer;
        }
        body {
            padding-top: 80px;
        }
        h1, h2, h3 {
            color: #333;
            text-align: center;
        }
        h1 { font-size: 2.5em; }
        h2 { color: #0066cc; font-size: 2em; }
        p { font-size: 1.2em; margin-bottom: 15px; }
        .card {
            background-color: #ffffff;
            border-radius: 8px;
            box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1);
            padding: 20px;
            margin-bottom: 20px;
        }
        .divider {
            height: 2px;
            background-color: #e0e0e0;
            margin: 30px 0;
            border-radius: 4px;
        }
        /* Botones de expandir y colapsar todo */
        .expand-collapse-buttons {
            text-align: center;
            margin: 15px 0;
        }
        .expand-collapse-buttons button {
            background-color: #0066cc;
            color: white;
            padding: 10px 15px;
            font-size: 1em;
            margin: 5px;
            border: none;
            border-radius: 5px;
            cursor: pointer;
            transition: background-color 0.3s;
        }
        .expand-collapse-buttons button:hover {
            background-color: #005bb5;
        }
        /* Estilos para el contenido colapsable */
        .collapsible {
            cursor: pointer;
            font-weight: bold;
            background-color: #0066cc;
            color: white;
            border: none;
            outline: none;
            font-size: 1.1em;
            padding: 10px;
            width: 100%;
            text-align: left;
            border-radius: 5px;
            box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.2);
            transition: background-color 0.3s;
        }
        .content {
            display: none;
            padding: 15px;
            background-color: #f1f1f1;
            border-radius: 8px;
        }
    </style>
</head>
<body>

    <div class="navbar">
        <a onclick="document.getElementById('definicion').scrollIntoView();">Definición de Grafo Dirigido</a> |
        <a onclick="document.getElementById('representacion').scrollIntoView();">Representación de Grafos</a> |
        <a onclick="document.getElementById('ejemplos').scrollIntoView();">Ejemplos en el Mundo Real</a>
    </div>

    <h1>Introducción a Grafos Dirigidos</h1>

    <div class="expand-collapse-buttons">
        <button onclick="expandAll()">Expandir Todo</button>
        <button onclick="collapseAll()">Colapsar Todo</button>
    </div>

    <button id="definicion" class="collapsible">Definición de Grafo Dirigido</button>
    <div class="content">
        <div class="card">
            <p>Un <strong>grafo dirigido</strong> es una estructura matemática compuesta por un conjunto de nodos (o vértices) y un conjunto de aristas que tienen una dirección definida. En un grafo dirigido, cada arista conecta un nodo de origen con un nodo de destino, estableciendo una relación asimétrica entre los nodos.</p>
        </div>
    </div>

    <div class="divider"></div>

    <button id="representacion" class="collapsible">Representación de Grafos: Nodos y Aristas</button>
    <div class="content">
        <div class="card">
            <p>Existen varias formas de representar un grafo dirigido. Las dos representaciones más comunes son la <strong>matriz de adyacencia</strong> y la <strong>lista de adyacencia</strong>.</p>
        </div>
    </div>

    <div class="divider"></div>

    <button id="ejemplos" class="collapsible">Ejemplos de Grafos Dirigidos en el Mundo Real</button>
    <div class="content">
        <div class="card">
            <h3>Redes de Tránsito y Transporte</h3>
            <p>Las calles y rutas de transporte se pueden modelar con un grafo dirigido donde los nodos representan intersecciones y las aristas dirigidas representan rutas unidireccionales.</p>
            <h3>Sistemas de Dependencias en Software</h3>
            <p>En el desarrollo de software, los módulos de código dependen unos de otros en un orden específico, modelado con grafos dirigidos.</p>
            <h3>Redes de Comunicación y Flujos de Datos</h3>
            <p>En redes de computadoras, los grafos dirigidos representan el flujo de datos entre dispositivos. Cada nodo representa un dispositivo y cada arista dirigida un enlace de comunicación.</p>
        </div>
    </div>

    <script>
        // Expande todas las secciones
        function expandAll() {
            const contents = document.getElementsByClassName("content");
            for (const content of contents) {
                content.style.display = "block";
            }
        }

        // Colapsa todas las secciones
        function collapseAll() {
            const contents = document.getElementsByClassName("content");
            for (const content of contents) {
                content.style.display = "none";
            }
        }

        // Añade funcionalidad de colapsado a cada botón
        const coll = document.getElementsByClassName("collapsible");
        for (let i = 0; i < coll.length; i++) {
            coll[i].addEventListener("click", function() {
                const content = this.nextElementSibling;
                content.style.display = content.style.display === "block" ? "none" : "block";
            });
        }
    </script>
</body>
</html>
"""

# Mostrar el contenido HTML
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Referencias sobre Algoritmo de Dijkstra</title>
#     <style>
#         /* Estilos básicos */
#         body {
#             font-family: 'Georgia', serif;
#             line-height: 1.8;
#             margin: 20px;
#             padding: 20px;
#             background-color: #f9f9f9;
#         }
#         .navbar {
#             background-color: #0066cc;
#             color: white;
#             padding: 10px 15px;
#             text-align: center;
#             font-size: 1.2em;
#             position: fixed;
#             width: 100%;
#             top: 0;
#             left: 0;
#             z-index: 1000;
#         }
#         .navbar a {
#             color: white;
#             text-decoration: none;
#             padding: 0 10px;
#             cursor: pointer;
#         }
#         body {
# ...

# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Concepto de Árbol en Teoría de Grafos</title>
    <style>
        /* Estilos básicos */
        body {
            font-family: 'Georgia', serif;
            line-height: 1.8;
            margin: 20px;
            padding: 20px;
            background: linear-gradient(135deg, #f9f9f9, #e0e0e0);
            background-attachment: fixed;
        }
        /* Barra de navegación */
        .navbar {
            background-color: #0066cc;
            color: white;
            padding: 10px 15px;
            text-align: center;
            font-size: 1.2em;
            position: fixed;
            width: 100%;
            top: 0;
            left: 0;
            z-index: 1000;
        }
        .navbar a {
            color: white;
            text-decoration: none;
            padding: 0 10px;
        }
        /* Ajuste de espacio por la barra */
        body {
            padding-top: 70px;
        }
        h1 {
            color: #333;
            font-size: 2.5em;
            text-align: center;
        }
        h3 {
            color: #333;
            font-size: 1.5em;
        }
        p {
            font-size: 1.2em;
            margin-bottom: 15px;
        }
        ul, ol {
            margin-left: 20px;
            margin-bottom: 20px;
        }
        /* Estilo de tarjetas de contenido */
        .card {
            background-color: #ffffff;
            border-radius: 8px;
            box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1);
            padding: 20px;
            margin-bottom: 20px;
        }
        /* Botones colapsables */
        .collapsible {
            cursor: pointer;
            font-weight: bold;
            text-align: left;
            background-color: #0066cc;
            color: white;
            border: none;
            outline: none;
            font-size: 1.1em;
            padding: 10px;
            width: 100%;
            text-align: left;
            border-radius: 5px;
            box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.2);
        }
        .content {
            display: none;
            padding: 15px;
            background-color: #f1f1f1;
            overflow: hidden;
            transition: max-height 0.3s ease-out;
            border-radius: 8px;
        }
        /* Botones para expandir y colapsar todo */
        .expand-collapse-buttons {
            text-align: center;
            margin: 15px 0;
        }
        .expand-collapse-buttons button {
            background-color: #0066cc;
            color: white;
            padding: 10px 15px;
            font-size: 1em;
            margin: 5px;
            border: none;
            border-radius: 5px;
            cursor: pointer;
        }
        .expand-collapse-buttons button:hover {
            background-color: #005bb5;
        }
    </style>
</head>
<body>

    <div class="navbar">
        <a href="#definicion">Definición de Árbol</a> |
        <a href="#expansion">Árboles de Expansión</a> |
        <a href="#dirigidos">Árboles en Grafos Dirigidos vs. No Dirigidos</a> |
        <a href="#conclusion">Conclusión</a>
    </div>

    <h1>Concepto de Árbol en Teoría de Grafos</h1>

    <div class="expand-collapse-buttons">
        <button onclick="expandAll()">Expandir Todo</button>
        <button onclick="collapseAll()">Colapsar Todo</button>
    </div>

    <button id="definicion" class="collapsible">Definición de Árbol en Grafos (Acíclico y Conexo)</button>
    <div class="content">
        <div class="card">
            <p>En teoría de grafos, un <strong>árbol</strong> es un grafo que es a la vez <strong>acíclico</strong> y <strong>conexo</strong>.</p>
            <ul>
                <li><strong>Acíclico</strong>: No contiene ciclos, es decir, no hay ninguna secuencia de aristas que comience y termine en el mismo nodo.</li>
                <li><strong>Conexo</strong>: Existe un camino entre cualquier par de nodos en el grafo, lo que garantiza que todos los nodos están interconectados sin quedar aislados.</li>
            </ul>
            <p>Un árbol puede definirse formalmente como un grafo no dirigido <em>T = (V, E)</em>, donde:</p>
            <ul>
                <li><em>V</em> es el conjunto de nodos o vértices.</li>
                <li><em>E</em> es el conjunto de aristas que conectan los nodos.</li>
            </ul>
            <p>Para un grafo de <em>n</em> nodos, un árbol tiene exactamente <em>n - 1</em> aristas, lo que garantiza su conectividad y minimización.</p>
        </div>
    </div>

    <button id="expansion" class="collapsible">Árboles de Expansión en Grafos y su Relación con los Caminos</button>
    <div class="content">
        <div class="card">
            <p>Un <strong>árbol de expansión</strong> es un subgrafo que incluye todos los nodos del grafo original y un subconjunto de sus aristas para formar una estructura acíclica y conexa.</p>
            <p>Propiedades:</p>
            <ul>
                <li><strong>Conectividad Completa</strong>: Conecta todos los nodos del grafo.</li>
                <li><strong>Número de Aristas</strong>: Contiene exactamente <em>n - 1</em> aristas.</li>
                <li><strong>Unicidad de Caminos</strong>: Un solo camino entre cualquier par de nodos.</li>
            </ul>
            <p>En grafos ponderados, el <strong>árbol de expansión mínima (MST)</strong> es aquel en el que la suma de los pesos de las aristas es mínima. Algoritmos como Prim y Kruskal son comunes para encontrar el MST.</p>
        </div>
    </div>

    <button id="dirigidos" class="collapsible">Árboles en Grafos Dirigidos vs. No Dirigidos</button>
    <div class="content">
        <div class="card">
            <h3>Árboles en Grafos No Dirigidos</h3>
            <p>Características:</p>
            <ul>
                <li><strong>Unicidad de Caminos</strong>: Un único camino entre cualquier par de nodos.</li>
                <li><strong>Simetría en Conexiones</strong>: Las conexiones no tienen dirección.</li>
            </ul>

            <h3>Árboles en Grafos Dirigidos</h3>
            <p>En un <strong>árbol dirigido</strong>, las aristas tienen una dirección, formando una estructura jerárquica desde un nodo raíz hacia otros nodos.</p>
            <ul>
                <li><strong>Nodo Raíz</strong>: Un nodo origen del cual emanan todas las conexiones.</li>
                <li><strong>Dirección de los Caminos</strong>: Los caminos siguen la dirección de las aristas.</li>
                <li><strong>Organización Jerárquica</strong>: Ideal para representar relaciones jerárquicas.</li>
            </ul>

            <h3>Ejemplos de Uso</h3>
            <ol>
                <li><strong>Árboles de Decisión</strong>: En IA, para representar decisiones con flujo unidireccional.</li>
                <li><strong>Árboles de Dependencias</strong>: En sistemas operativos, muestran dependencias entre procesos.</li>
                <li><strong>Organización de Bases de Datos</strong>: Representan relaciones jerárquicas en bases de datos.</li>
            </ol>
        </div>
    </div>

    <button id="conclusion" class="collapsible">Conclusión</button>
    <div class="content">
        <div class="card">
            <p>Los árboles son esenciales en teoría de grafos, usados para organizar datos, optimizar redes y modelar relaciones jerárquicas.</p>
            <p>Los <strong>árboles de expansión</strong> en grafos no dirigidos optimizan redes y minimizan costos, mientras que los <strong>árboles dirigidos</strong> modelan flujos y dependencias jerárquicas en áreas como telecomunicaciones y bases de datos.</p>
        </div>
    </div>

    <script>
        /* Función para expandir o colapsar todas las secciones */
        function expandAll() {
            var contents = document.getElementsByClassName("content");
            for (var i = 0; i < contents.length; i++) {
                contents[i].style.display = "block";
            }
        }
        function collapseAll() {
            var contents = document.getElementsByClassName("content");
            for (var i = 0; i < contents.length; i++) {
                contents[i].style.display = "none";
            }
        }

        /* Funcionalidad para cada botón colapsable */
        var coll = document.getElementsByClassName("collapsible");
        for (var i = 0; i < coll.length; i++) {
            coll[i].addEventListener("click", function() {
                this.classList.toggle("active");
                var content = this.nextElementSibling;
                if (content.style.display === "block") {
                    content.style.display = "none";
                } else {
                    content.style.display = "block";
                }
            });
        }
    </script>
</body>
</html>
"""

# Mostrar el contenido HTML
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Concepto de Árbol en Teoría de Grafos</title>
#     <style>
#         /* Estilos básicos */
#         body {
#             font-family: 'Georgia', serif;
#             line-height: 1.8;
#             margin: 20px;
#             padding: 20px;
#             background: linear-gradient(135deg, #f9f9f9, #e0e0e0);
#             background-attachment: fixed;
#         }
#         /* Barra de navegación */
#         .navbar {
#             background-color: #0066cc;
#             color: white;
#             padding: 10px 15px;
#             text-align: center;
#             font-size: 1.2em;
#             position: fixed;
#             width: 100%;
#             top: 0;
#             left: 0;
#             z-index: 1000;
#         }
#         .navbar a {
#             color: white;
#             text-decoration: none;
# ...

# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Planteamiento del Problema: Caminos Mínimos</title>
    <style>
        /* Estilos básicos */
        body {
            font-family: 'Georgia', serif;
            line-height: 1.8;
            margin: 20px;
            padding: 20px;
            background: linear-gradient(135deg, #f9f9f9, #e0e0e0);
            background-attachment: fixed;
        }
        /* Barra de navegación */
        .navbar {
            background-color: #0066cc;
            color: white;
            padding: 10px 15px;
            text-align: center;
            font-size: 1.2em;
            position: fixed;
            width: 100%;
            top: 0;
            left: 0;
            z-index: 1000;
        }
        .navbar a {
            color: white;
            text-decoration: none;
            padding: 0 10px;
        }
        /* Ajuste de espacio por la barra */
        body {
            padding-top: 70px;
        }
        h1 {
            color: #333;
            font-size: 2.5em;
            text-align: center;
        }
        h3 {
            color: #333;
            font-size: 1.5em;
        }
        p {
            font-size: 1.2em;
            margin-bottom: 15px;
        }
        ul, ol {
            margin-left: 20px;
            margin-bottom: 20px;
        }
        /* Estilo de tarjetas de contenido */
        .card {
            background-color: #ffffff;
            border-radius: 8px;
            box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1);
            padding: 20px;
            margin-bottom: 20px;
        }
        /* Botones colapsables */
        .collapsible {
            cursor: pointer;
            font-weight: bold;
            text-align: left;
            background-color: #0066cc;
            color: white;
            border: none;
            outline: none;
            font-size: 1.1em;
            padding: 10px;
            width: 100%;
            text-align: left;
            border-radius: 5px;
            box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.2);
        }
        .content {
            display: none;
            padding: 15px;
            background-color: #f1f1f1;
            overflow: hidden;
            transition: max-height 0.3s ease-out;
            border-radius: 8px;
        }
        /* Botones para expandir y colapsar todo */
        .expand-collapse-buttons {
            text-align: center;
            margin: 15px 0;
        }
        .expand-collapse-buttons button {
            background-color: #0066cc;
            color: white;
            padding: 10px 15px;
            font-size: 1em;
            margin: 5px;
            border: none;
            border-radius: 5px;
            cursor: pointer;
        }
        .expand-collapse-buttons button:hover {
            background-color: #005bb5;
        }
    </style>
</head>
<body>

    <div class="navbar">
        <a href="#definicion">Definición</a> |
        <a href="#tipos">Tipos de Problemas</a> |
        <a href="#importancia">Importancia de los Pesos</a> |
        <a href="#aplicaciones">Aplicaciones</a>
    </div>

    <h1>Planteamiento del Problema: Caminos Mínimos</h1>

    <div class="expand-collapse-buttons">
        <button onclick="expandAll()">Expandir Todo</button>
        <button onclick="collapseAll()">Colapsar Todo</button>
    </div>

    <button id="definicion" class="collapsible">Definición del Problema de Caminos Mínimos</button>
    <div class="content">
        <div class="card">
            <p>El problema de caminos mínimos se formula de la siguiente manera: dado un grafo <em>G = (V, E)</em>, donde <em>V</em> es el conjunto de nodos (o vértices) y <em>E</em> es el conjunto de aristas (o conexiones) entre estos nodos, cada arista tiene un peso asociado que representa el "costo" de desplazarse de un nodo a otro.</p>
            <p>El objetivo es encontrar el camino con el costo total mínimo entre un nodo de origen <em>s</em> y un nodo de destino <em>t</em> (o entre un nodo de origen y todos los demás nodos, en el caso del problema de caminos mínimos desde una fuente).</p>
        </div>
    </div>

    <button id="tipos" class="collapsible">Tipos de Problemas de Caminos Mínimos</button>
    <div class="content">
        <div class="card">
            <ul>
                <li><strong>Caminos mínimos entre dos nodos específicos</strong>: Se busca el camino de menor costo entre un nodo de origen <em>s</em> y un nodo de destino <em>t</em>.</li>
                <li><strong>Caminos mínimos desde un nodo origen a todos los nodos (caminos de una sola fuente)</strong>: Este problema busca calcular la distancia mínima desde un nodo específico <em>s</em> a todos los otros nodos del grafo.</li>
                <li><strong>Caminos mínimos entre todos los pares de nodos (caminos de múltiples fuentes)</strong>: Aquí se calcula el camino mínimo entre cada par de nodos en el grafo. Este problema es útil en análisis de redes complejas.</li>
            </ul>
            <p>Estos problemas se resuelven con algoritmos especializados, como el algoritmo de Dijkstra para grafos sin pesos negativos o el algoritmo de Bellman-Ford que puede manejar pesos negativos. Otro algoritmo utilizado para resolver el problema de caminos mínimos entre todos los pares es el algoritmo de Floyd-Warshall.</p>
        </div>
    </div>

    <button id="importancia" class="collapsible">Importancia de los Pesos en las Aristas</button>
    <div class="content">
        <div class="card">
            <p>En el problema de caminos mínimos, los pesos en las aristas son fundamentales, ya que determinan el "costo" de desplazarse de un nodo a otro. Este costo puede representar una variedad de métricas según el contexto:</p>
            <ul>
                <li><strong>Distancia física</strong>: En redes de transporte o navegación, los pesos pueden representar distancias físicas entre ubicaciones, como kilómetros entre ciudades.</li>
                <li><strong>Tiempo de viaje</strong>: En sistemas de tráfico, los pesos de las aristas pueden representar el tiempo necesario para desplazarse entre puntos. Esto es común en aplicaciones de mapas y navegación GPS.</li>
                <li><strong>Costos monetarios</strong>: En redes de logística o distribución de productos, el peso puede representar el costo monetario de transportar bienes entre puntos, tomando en cuenta factores como combustible o tarifas de transporte.</li>
                <li><strong>Capacidad y flujo</strong>: En redes de telecomunicaciones o suministro de energía, el peso podría representar restricciones de capacidad o costos de flujo de recursos, como ancho de banda en una conexión de datos o consumo de energía en una línea de transmisión.</li>
            </ul>
            <p>Los pesos en las aristas permiten adaptar el problema de caminos mínimos a diferentes aplicaciones prácticas, donde el objetivo es minimizar una métrica específica. La correcta asignación de estos pesos es crucial para que los resultados de los algoritmos de caminos mínimos sean útiles en contextos reales.</p>
        </div>
    </div>

    <button id="aplicaciones" class="collapsible">Aplicaciones del Problema de Caminos Mínimos</button>
    <div class="content">
        <div class="card">
            <h3>1. Redes de Transporte y Navegación</h3>
            <p><strong>Descripción</strong>: En las redes de transporte (como carreteras, redes ferroviarias, y rutas de vuelos), el problema de caminos mínimos se utiliza para calcular la ruta más corta o más rápida entre dos ubicaciones.</p>
            <p><strong>Ejemplo</strong>: En aplicaciones de navegación GPS, como Google Maps o Waze, se calcula el camino mínimo en función de la distancia o el tiempo estimado de viaje.</p>
            <p><strong>Beneficios</strong>: Optimizar rutas ayuda a reducir el tiempo de viaje y el consumo de combustible, mejorando la eficiencia en el transporte y reduciendo costos tanto para empresas como para individuos.</p>

            <h3>2. Rutas en Redes de Comunicación y Telecomunicaciones</h3>
            <p><strong>Descripción</strong>: En redes de comunicación (como Internet), se requiere transmitir datos entre nodos de forma eficiente y rápida. El problema de caminos mínimos permite encontrar las rutas de transmisión de datos con menor costo en términos de latencia o ancho de banda.</p>
            <p><strong>Ejemplo</strong>: Los protocolos de enrutamiento, como el Protocolo de Enrutamiento de Información Interior (IGP), implementan algoritmos de caminos mínimos para determinar la ruta más eficiente entre routers en una red.</p>
            <p><strong>Beneficios</strong>: Utilizar caminos mínimos en redes de comunicación mejora la velocidad de transmisión y reduce la congestión en la red, lo cual es crucial para mantener la calidad de servicio en aplicaciones sensibles al tiempo.</p>

            <h3>3. Optimización en Redes de Flujo (Suministro de Energía, Logística)</h3>
            <p><strong>Descripción</strong>: En sistemas de logística y suministro de energía, el problema de caminos mínimos ayuda a determinar la ruta óptima para distribuir productos o energía desde fuentes de suministro a puntos de consumo.</p>
            <p><strong>Ejemplo en Logística</strong>: Empresas como Amazon o FedEx utilizan algoritmos de caminos mínimos para optimizar la distribución de mercancías desde los centros de distribución hasta los destinos finales.</p>
            <p><strong>Ejemplo en Energía</strong>: En redes eléctricas, los caminos mínimos ayudan a minimizar la pérdida de energía en la transmisión de electricidad desde las plantas generadoras hasta los consumidores.</p>
            <p><strong>Beneficios</strong>: En logística, el uso de caminos mínimos reduce costos y aumenta la eficiencia de la cadena de suministro. En redes eléctricas, optimizar las rutas de energía contribuye a reducir pérdidas y mejorar la estabilidad del sistema.</p>
        </div>
    </div>

    <script>
        /* Función para expandir o colapsar todas las secciones */
        function expandAll() {
            var contents = document.getElementsByClassName("content");
            for (var i = 0; i < contents.length; i++) {
                contents[i].style.display = "block";
            }
        }
        function collapseAll() {
            var contents = document.getElementsByClassName("content");
            for (var i = 0; i < contents.length; i++) {
                contents[i].style.display = "none";
            }
        }

        /* Funcionalidad para cada botón colapsable */
        var coll = document.getElementsByClassName("collapsible");
        for (var i = 0; i < coll.length; i++) {
            coll[i].addEventListener("click", function() {
                this.classList.toggle("active");
                var content = this.nextElementSibling;
                if (content.style.display === "block") {
                    content.style.display = "none";
                } else {
                    content.style.display = "block";
                }
            });
        }
    </script>
</body>
</html>
"""

# Mostrar el contenido HTML
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Planteamiento del Problema: Caminos Mínimos</title>
#     <style>
#         /* Estilos básicos */
#         body {
#             font-family: 'Georgia', serif;
#             line-height: 1.8;
#             margin: 20px;
#             padding: 20px;
#             background: linear-gradient(135deg, #f9f9f9, #e0e0e0);
#             background-attachment: fixed;
#         }
#         /* Barra de navegación */
#         .navbar {
#             background-color: #0066cc;
#             color: white;
#             padding: 10px 15px;
#             text-align: center;
#             font-size: 1.2em;
#             position: fixed;
#             width: 100%;
#             top: 0;
#             left: 0;
#             z-index: 1000;
#         }
#         .navbar a {
#             color: white;
#             text-decoration: none;
# ...

# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>El Algoritmo de Dijkstra</title>
    <style>
        /* Estilos básicos */
        body {
            font-family: 'Georgia', serif;
            line-height: 1.8;
            margin: 20px;
            padding: 20px;
            background-color: #f9f9f9;
            background-image: url('https://www.transparenttextures.com/patterns/light-paper-fibers.png');
            background-size: cover;
            background-attachment: fixed;
            background-blend-mode: lighten;
        }
        .navbar {
            background-color: #0066cc;
            color: white;
            padding: 10px 15px;
            text-align: center;
            font-size: 1.2em;
            position: fixed;
            width: 100%;
            top: 0;
            left: 0;
            z-index: 1000;
        }
        body {
            padding-top: 60px;
        }
        h1, h2, h3 {
            color: #333;
            text-align: center;
        }
        h1 { font-size: 2.5em; }
        h2 { color: #0066cc; font-size: 2em; }
        h3 { font-size: 1.5em; }
        p { font-size: 1.2em; margin-bottom: 15px; }
        ul, ol { margin-left: 20px; margin-bottom: 20px; }
        .card {
            background-color: #ffffff;
            border-radius: 8px;
            box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1);
            padding: 20px;
            margin-bottom: 20px;
        }
        .divider {
            height: 2px;
            background-color: #e0e0e0;
            margin: 30px 0;
            border-radius: 4px;
        }
        .collapsible {
            cursor: pointer;
            font-weight: bold;
            text-align: left;
            background-color: #0066cc;
            color: white;
            border: none;
            outline: none;
            font-size: 1.1em;
            padding: 10px;
            width: 100%;
            text-align: left;
        }
        .content {
            display: none;
            padding: 15px;
            background-color: #f1f1f1;
        }
    </style>
</head>
<body>
    <div class="navbar">El Algoritmo de Dijkstra</div>

    <h1>El Algoritmo de Dijkstra</h1>

    <button class="collapsible">Introducción a Dijkstra y su Objetivo</button>
    <div class="content">
        <div class="card">
            <p>El <strong>Algoritmo de Dijkstra</strong> es un método ampliamente utilizado en teoría de grafos para encontrar el <strong>camino más corto</strong> desde un nodo de origen a todos los demás nodos en un grafo ponderado. Este algoritmo, propuesto por el científico informático Edsger Dijkstra en 1956, busca resolver problemas de optimización en redes, como la determinación de la ruta más eficiente en mapas, redes de transporte, y redes de comunicación.</p>
            <p>El objetivo principal de Dijkstra es encontrar el <strong>camino de menor costo</strong> desde un punto de partida hasta todos los puntos alcanzables en un grafo, bajo la condición de que las aristas tengan pesos no negativos. Esto lo hace especialmente útil en aplicaciones de redes de carreteras y sistemas de navegación, donde el peso suele representar la distancia, el tiempo de viaje o el costo asociado.</p>
        </div>
    </div>

    <div class="divider"></div>

    <button class="collapsible">Funcionamiento General del Algoritmo</button>
    <div class="content">
        <div class="card">
            <p>El algoritmo de Dijkstra sigue una estrategia <strong>voraz (greedy)</strong>, expandiendo el conjunto de nodos alcanzables en orden creciente de distancia desde el nodo de origen. A continuación se describen los pasos principales:</p>
            <ol>
                <li><strong>Inicialización</strong>: Se asigna una distancia de 0 al nodo de origen y una distancia infinita a todos los demás nodos. Esto significa que, al inicio, solo se conoce la distancia del nodo de origen a sí mismo, mientras que las distancias a los demás nodos son desconocidas y se representan como infinitas.</li>
                <li><strong>Expansión y actualización de distancias</strong>:
                    <ul>
                        <li>Se selecciona el nodo no visitado con la menor distancia conocida desde el origen. Este nodo pasa a ser "visitado" y no será reconsiderado.</li>
                        <li>Desde este nodo, se evalúan sus vecinos: para cada vecino, se calcula una distancia potencial como la suma de la distancia al nodo actual más el peso de la arista que conecta al vecino.</li>
                        <li>Si esta distancia calculada es menor que la distancia previamente registrada para el vecino, se actualiza la distancia del vecino y se guarda el nodo actual como predecesor en el camino de menor costo hacia él.</li>
                    </ul>
                </li>
                <li><strong>Repetición</strong>: Este proceso de expansión y actualización se repite hasta que todos los nodos alcanzables hayan sido visitados y sus distancias mínimas desde el origen se hayan determinado. El resultado es un árbol de caminos mínimos que muestra la ruta más corta desde el nodo de origen a todos los demás nodos.</li>
            </ol>
        </div>
    </div>

    <div class="divider"></div>

    <button class="collapsible">Expansión del Árbol de Caminos Mínimos</button>
    <div class="content">
        <div class="card">
            <p>A medida que el algoritmo avanza, construye un "árbol de caminos mínimos", en el que cada nodo tiene un camino definido desde el nodo de origen con la menor distancia posible. En este contexto, el "árbol" se refiere al conjunto de caminos de menor costo que conectan el nodo de origen con cada nodo alcanzable, evitando ciclos y minimizando las distancias.</p>
            <p>Este árbol se expande de forma ordenada, nodo por nodo, en función de la distancia mínima alcanzable, lo cual garantiza que cuando un nodo es marcado como "visitado", ya se ha encontrado el camino más corto hacia él.</p>
        </div>
    </div>

    <div class="divider"></div>

    <button class="collapsible">Uso de Estructuras de Datos Tipo Heap para Eficiencia</button>
    <div class="content">
        <div class="card">
            <p>Para mejorar la eficiencia del algoritmo, especialmente en grafos grandes, se utilizan estructuras de datos como el <strong>montículo (heap)</strong>, específicamente un heap de min-prioridad. Esto permite seleccionar rápidamente el nodo no visitado con la menor distancia conocida, lo que es crucial para reducir el tiempo de ejecución.</p>
            <p>En lugar de buscar el nodo de menor distancia en una lista de todos los nodos no visitados (lo cual sería costoso en tiempo de procesamiento), el heap de min-prioridad organiza los nodos de manera que el acceso al nodo de menor costo sea inmediato. Cuando se actualizan las distancias de los vecinos, el heap se ajusta dinámicamente para que la selección del siguiente nodo sea eficiente. Este enfoque reduce la complejidad temporal del algoritmo de O(V^2) (donde V es el número de nodos) a O((V + E) log V), donde E es el número de aristas del grafo.</p>
        </div>
    </div>

    <div class="divider"></div>

    <button class="collapsible">Ventajas y Limitaciones de Dijkstra</button>
    <div class="content">
        <div class="card">
            <ul>
                <li><strong>No admite pesos negativos</strong>: El algoritmo de Dijkstra no puede manejar grafos con aristas de peso negativo, ya que esto podría llevar a soluciones incorrectas. Los pesos negativos pueden causar que los caminos más cortos se vuelvan más largos después de una actualización, lo cual contradice la suposición fundamental del algoritmo.</li>
                <li><strong>Es voraz y no óptimo para todos los problemas de caminos mínimos</strong>: Aunque Dijkstra es ideal para grafos con pesos no negativos, otros algoritmos, como el algoritmo de Bellman-Ford, son más adecuados para grafos que contienen pesos negativos, aunque a costa de una mayor complejidad temporal.</li>
            </ul>
        </div>
    </div>

    <div class="divider"></div>

    <button class="collapsible">Conclusión</button>
    <div class="content">
        <div class="card">
            <p>El Algoritmo de Dijkstra es una herramienta poderosa y eficiente para encontrar caminos mínimos en redes con pesos no negativos. Su uso de una estrategia voraz y de estructuras de datos avanzadas como el heap de min-prioridad lo hace ideal para aplicaciones prácticas en redes de transporte y telecomunicaciones. Aunque tiene limitaciones en grafos con pesos negativos, sigue siendo uno de los algoritmos más importantes en teoría de grafos y optimización de rutas.</p>
        </div>
    </div>

    <script>
        var coll = document.getElementsByClassName("collapsible");
        for (var i = 0; i < coll.length; i++) {
            coll[i].addEventListener("click", function() {
                this.classList.toggle("active");
                var content = this.nextElementSibling;
                if (content.style.display === "block") {
                    content.style.display = "none";
                } else {
                    content.style.display = "block";
                }
            });
        }
    </script>
</body>
</html>
"""

# Mostrar el contenido HTML
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>El Algoritmo de Dijkstra</title>
#     <style>
#         /* Estilos básicos */
#         body {
#             font-family: 'Georgia', serif;
#             line-height: 1.8;
#             margin: 20px;
#             padding: 20px;
#             background-color: #f9f9f9;
#             background-image: url('https://www.transparenttextures.com/patterns/light-paper-fibers.png');
#             background-size: cover;
#             background-attachment: fixed;
#             background-blend-mode: lighten;
#         }
#         .navbar {
#             background-color: #0066cc;
#             color: white;
#             padding: 10px 15px;
#             text-align: center;
#             font-size: 1.2em;
#             position: fixed;
#             width: 100%;
#             top: 0;
#             left: 0;
# ...

# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Implementación Práctica del Algoritmo de Dijkstra</title>
    <style>
        body {
            font-family: 'Georgia', serif;
            line-height: 1.8;
            margin: 20px;
            padding: 20px;
            background: linear-gradient(135deg, #f9f9f9, #e0e0e0);
            background-attachment: fixed;
        }
        .navbar {
            background-color: #0066cc;
            color: white;
            padding: 10px 15px;
            text-align: center;
            font-size: 1.2em;
            position: fixed;
            width: 100%;
            top: 0;
            left: 0;
            z-index: 1000;
        }
        .navbar a {
            color: white;
            text-decoration: none;
            padding: 0 10px;
        }
        body {
            padding-top: 70px;
        }
        h1 {
            color: #333;
            font-size: 2.5em;
            text-align: center;
        }
        h3 {
            color: #333;
            font-size: 1.5em;
        }
        p {
            font-size: 1.2em;
            margin-bottom: 15px;
        }
        ul, ol {
            margin-left: 20px;
            margin-bottom: 20px;
        }
        .card {
            background-color: #ffffff;
            border-radius: 8px;
            box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1);
            padding: 20px;
            margin-bottom: 20px;
        }
        .collapsible {
            cursor: pointer;
            font-weight: bold;
            text-align: left;
            background-color: #0066cc;
            color: white;
            border: none;
            outline: none;
            font-size: 1.1em;
            padding: 10px;
            width: 100%;
            text-align: left;
            border-radius: 5px;
            box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.2);
        }
        .content {
            display: none;
            padding: 15px;
            background-color: #f1f1f1;
            overflow: hidden;
            transition: max-height 0.3s ease-out;
            border-radius: 8px;
        }
        .expand-collapse-buttons {
            text-align: center;
            margin: 15px 0;
        }
        .expand-collapse-buttons button {
            background-color: #0066cc;
            color: white;
            padding: 10px 15px;
            font-size: 1em;
            margin: 5px;
            border: none;
            border-radius: 5px;
            cursor: pointer;
        }
        .expand-collapse-buttons button:hover {
            background-color: #005bb5;
        }
    </style>
</head>
<body>

    <div class="navbar">
        <a href="#ejemplo">Ejemplo de Código</a> |
        <a href="#inicializacion">Inicialización de Distancias</a> |
        <a href="#seleccion">Selección del Nodo Más Cercano</a> |
        <a href="#actualizacion">Actualización de Distancias</a> |
        <a href="#prueba">Prueba y Demostración</a>
    </div>

    <h1>Implementación Práctica del Algoritmo de Dijkstra</h1>

    <div class="expand-collapse-buttons">
        <button onclick="expandAll()">Expandir Todo</button>
        <button onclick="collapseAll()">Colapsar Todo</button>
    </div>

    <button id="ejemplo" class="collapsible">Ejemplo de Código en Python para Resolver el Problema de Caminos Mínimos</button>
    <div class="content">
        <div class="card">
            <p>El siguiente código implementa el Algoritmo de Dijkstra para encontrar los caminos mínimos en un grafo ponderado. Utiliza <code>networkx</code> para crear y manejar el grafo, y <code>matplotlib</code> para visualizar la progresión del algoritmo en un entorno interactivo de Google Colab.</p>
        </div>
    </div>

    <button id="inicializacion" class="collapsible">Inicialización de Distancias</button>
    <div class="content">
        <div class="card">
            <p>Al comenzar, se establece la distancia del nodo de inicio en 0 y la de los demás nodos en infinito, ya que no se conoce aún la ruta óptima hacia ellos. Se utiliza una cola de prioridad para seleccionar siempre el nodo con la menor distancia acumulada.</p>
            <ul>
                <li><strong>Distancia Inicial</strong>: <code>distances = {node: float('inf') for node in G.nodes}</code></li>
                <li><strong>Nodo Inicial</strong>: Se establece en 0 la distancia del nodo de inicio, <code>distances[start_node] = 0</code>.</li>
                <li><strong>Cola de Prioridad</strong>: <code>heapq</code> permite extraer el nodo con la menor distancia de forma eficiente.</li>
            </ul>
        </div>
    </div>

    <button id="seleccion" class="collapsible">Selección del Nodo Más Cercano no Procesado</button>
    <div class="content">
        <div class="card">
            <p>Durante cada iteración, se extrae el nodo con la menor distancia de la cola de prioridad. Si la distancia registrada para este nodo es mayor que la actual, se omite para evitar cálculos innecesarios.</p>
            <ul>
                <li>Se utiliza <code>heapq.heappop(priority_queue)</code> para extraer el nodo con la menor distancia acumulada.</li>
                <li>Si la distancia es mayor que la registrada, se omite.</li>
            </ul>
        </div>
    </div>

    <button id="actualizacion" class="collapsible">Actualización de Distancias a los Vecinos</button>
    <div class="content">
        <div class="card">
            <p>Se revisan los nodos vecinos y se actualiza su distancia si se encuentra una ruta más corta a través del nodo actual. Las distancias se ajustan y el nodo se agrega nuevamente a la cola de prioridad.</p>
            <ul>
                <li>Para cada vecino, se calcula la distancia potencial: <code>distance = current_distance + weight['weight']</code>.</li>
                <li>Si esta distancia es menor que la registrada, se actualiza y se almacena el nodo actual como predecesor.</li>
            </ul>
        </div>
    </div>

    <button id="prueba" class="collapsible">Prueba y Demostración del Código con un Ejemplo Simple</button>
    <div class="content">
        <div class="card">
            <p>El código incluye una visualización paso a paso de Dijkstra en acción, donde se muestra el nodo actual y los caminos confirmados en cada paso. El grafo se actualiza dinámicamente para reflejar el progreso del algoritmo y resaltar los nodos procesados.</p>
            <p>Al final, se puede ver el camino más corto desde el nodo de inicio hasta el nodo de destino, destacando el uso de Dijkstra en grafos ponderados.</p>
        </div>
    </div>

    <script>
        /* Función para expandir o colapsar todas las secciones */
        function expandAll() {
            var contents = document.getElementsByClassName("content");
            for (var i = 0; i < contents.length; i++) {
                contents[i].style.display = "block";
            }
        }
        function collapseAll() {
            var contents = document.getElementsByClassName("content");
            for (var i = 0; i < contents.length; i++) {
                contents[i].style.display = "none";
            }
        }

        /* Funcionalidad para cada botón colapsable */
        var coll = document.getElementsByClassName("collapsible");
        for (var i = 0; i < coll.length; i++) {
            coll[i].addEventListener("click", function() {
                this.classList.toggle("active");
                var content = this.nextElementSibling;
                if (content.style.display === "block") {
                    content.style.display = "none";
                } else {
                    content.style.display = "block";
                }
            });
        }
    </script>
</body>
</html>
"""

# Mostrar el contenido HTML
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Implementación Práctica del Algoritmo de Dijkstra</title>
#     <style>
#         body {
#             font-family: 'Georgia', serif;
#             line-height: 1.8;
#             margin: 20px;
#             padding: 20px;
#             background: linear-gradient(135deg, #f9f9f9, #e0e0e0);
#             background-attachment: fixed;
#         }
#         .navbar {
#             background-color: #0066cc;
#             color: white;
#             padding: 10px 15px;
#             text-align: center;
#             font-size: 1.2em;
#             position: fixed;
#             width: 100%;
#             top: 0;
#             left: 0;
#             z-index: 1000;
#         }
#         .navbar a {
#             color: white;
#             text-decoration: none;
#             padding: 0 10px;
#         }
#         body {
# ...

# %%
# Importar las bibliotecas necesarias
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib.animation import FuncAnimation, PillowWriter
from IPython.display import HTML
from google.colab import files
import heapq
import matplotlib.patches as mpatches

# Crear el grafo y añadir aristas con sus respectivos pesos
G = nx.Graph()
edges = [
    ('d', 'a', 6), ('d', 'c', 1), ('d', 'e', 2),
    ('a', 'e', 2), ('a', 'b', 1), ('a', 'f', 2),
    ('b', 'g', 6), ('b', 'c', 3), ('e', 'f', 3),
    ('f', 'g', 3)
]
G.add_weighted_edges_from(edges)

# Definir posiciones para los nodos para una disposición más clara
pos = {
    'd': (0, 0), 'a': (1, 1), 'c': (2, 0), 'e': (0, 2),
    'f': (1, 3), 'b': (3, 1), 'g': (2.5, 3)
}

# Inicialización de Dijkstra
start_node = 'd'
distances = {node: float('inf') for node in G.nodes}
distances[start_node] = 0
previous = {node: None for node in G.nodes}
priority_queue = [(0, start_node)]
visited_order = []

# Ejecutar el algoritmo de Dijkstra y registrar el orden de visita
while priority_queue:
    current_distance, current_node = heapq.heappop(priority_queue)
    if current_distance > distances[current_node]:
        continue
    visited_order.append(current_node)
    for neighbor, weight in G[current_node].items():
        distance = current_distance + weight['weight']
        if distance < distances[neighbor]:
            distances[neighbor] = distance
            previous[neighbor] = current_node
            heapq.heappush(priority_queue, (distance, neighbor))

# Preparar la animación
fig, ax = plt.subplots(figsize=(8, 6))
fig.patch.set_facecolor('#F5F5F5')  # Fondo más claro
plt.axis('off')  # Ocultar los ejes
edge_labels = {(u, v): d['weight'] for u, v, d in G.edges(data=True)}

# Colores iniciales
node_colors = {node: '#D3D3D3' for node in G.nodes}  # Nodos no visitados en gris claro
edge_colors = {edge: '#000000' for edge in G.edges}  # Aristas no procesadas en negro

# Definir la leyenda con colores consistentes
legend_elements = [
    mpatches.Patch(color='#D3D3D3', label='Pendiente'),         # Gris claro
    mpatches.Patch(color='#00BFFF', label='Explorado'),         # Azul claro
    mpatches.Patch(color='#FF6347', label='Nodo actual'),       # Rojo tomate
    mpatches.Patch(color='#228B22', label='Ruta confirmada')    # Verde bosque
]

# Función para construir la ruta hasta un nodo dado
def construir_ruta(nodo):
    ruta = []
    while nodo is not None:
        ruta.append(nodo)
        nodo = previous[nodo]
    return ruta[::-1]  # Invertir para mostrar de inicio a fin

# Función para dibujar el grafo en cada paso
def draw_graph(ax, G, pos, step):
    ax.clear()  # Limpiar el gráfico en cada actualización
    plt.subplots_adjust(top=0.85, left=0.1, right=0.9, bottom=0.2)

    # Dibujar nodos y aristas hasta el paso actual
    nx.draw(G, pos, with_labels=True, node_color=[node_colors[n] for n in G.nodes], node_size=600, ax=ax)
    nx.draw_networkx_edges(G, pos, edge_color=[edge_colors[e] for e in G.edges], width=1.5, ax=ax)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

    # Dibujar la leyenda con colores consistentes
    ax.legend(handles=legend_elements, loc='upper center', bbox_to_anchor=(0.5, -0.1), framealpha=0.8, fontsize='small', ncol=4)

# Función de actualización para cada paso de la animación
def update(frame):
    # Obtener el nodo actual y construir la ruta confirmada hasta él
    current_node = visited_order[frame % len(visited_order)]
    path_nodes = construir_ruta(current_node)

    # Actualizar colores de nodos y aristas para la ruta confirmada
    for i in range(len(path_nodes) - 1):
        node_colors[path_nodes[i]] = '#00BFFF'  # Azul para nodos explorados
        edge_colors[(path_nodes[i], path_nodes[i+1])] = '#228B22'  # Verde para ruta confirmada

    # Marcar el nodo actual en rojo
    node_colors[current_node] = '#FF6347'  # Rojo para el nodo actual

    # Resaltar nodo de inicio y nodo objetivo
    nx.draw_networkx_nodes(G, pos, nodelist=[start_node], node_color='#00FFFF', node_shape='p', node_size=900, ax=ax)  # Inicio en cian
    nx.draw_networkx_nodes(G, pos, nodelist=['g'], node_color='#FFFF00', node_shape='s', node_size=900, ax=ax)  # Objetivo en amarillo

    # Actualizar el título para mostrar el nodo y distancia actual
    step = (frame % len(visited_order)) + 1
    current_dist = distances[current_node]
    plt.title(f"Paso {step}: Procesando nodo '{current_node}' con distancia acumulada {current_dist}", fontsize=12)

    # Dibujar el grafo
    draw_graph(ax, G, pos, step)

# Crear la animación con efecto continuo
ani = FuncAnimation(fig, update, frames=len(visited_order) * 3, interval=500, repeat=True)

# Guardar animación como MP4 y GIF
mp4_path = "/content/dijkstra_animation_continua.mp4"
ani.save(mp4_path, writer='ffmpeg', fps=2)  # FPS más alto para suavidad
gif_path = "/content/dijkstra_animation_continua.gif"
ani.save(gif_path, writer=PillowWriter(fps=2))
print("Animación guardada como MP4 y GIF con efecto continuo.")

# Mostrar el archivo MP4 en el notebook
HTML(f'<video width="600" controls><source src="{mp4_path}" type="video/mp4"></video>')

# Descargar los archivos MP4 y GIF
files.download(mp4_path)
files.download(gif_path)
# Out:
# Animación guardada como MP4 y GIF con efecto continuo.

# %%
# Importar las bibliotecas necesarias
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import heapq
import matplotlib.patches as mpatches

# Crear el grafo y añadir aristas con sus respectivos pesos
G = nx.Graph()
edges = [
    ('d', 'a', 6), ('d', 'c', 1), ('d', 'e', 2),
    ('a', 'e', 2), ('a', 'b', 1), ('a', 'f', 2),
    ('b', 'g', 6), ('b', 'c', 3), ('e', 'f', 3),
    ('f', 'g', 3)
]
G.add_weighted_edges_from(edges)

# Definir posiciones para los nodos para una disposición más clara
pos = {
    'd': (0, 0), 'a': (1, 1), 'c': (2, 0), 'e': (0, 2),
    'f': (1, 3), 'b': (3, 1), 'g': (2.5, 3)
}

# Inicialización de Dijkstra
start_node = 'd'
distances = {node: float('inf') for node in G.nodes}
distances[start_node] = 0
previous = {node: None for node in G.nodes}
priority_queue = [(0, start_node)]
visited_order = []

# Ejecutar el algoritmo de Dijkstra y registrar el orden de visita
while priority_queue:
    current_distance, current_node = heapq.heappop(priority_queue)
    if current_distance > distances[current_node]:
        continue
    visited_order.append(current_node)
    for neighbor, weight in G[current_node].items():
        distance = current_distance + weight['weight']
        if distance < distances[neighbor]:
            distances[neighbor] = distance
            previous[neighbor] = current_node
            heapq.heappush(priority_queue, (distance, neighbor))

# Preparar la animación
fig, ax = plt.subplots(figsize=(8, 6))
fig.patch.set_facecolor('#F5F5F5')  # Fondo más claro
plt.axis('off')  # Ocultar los ejes
edge_labels = {(u, v): d['weight'] for u, v, d in G.edges(data=True)}

# Colores iniciales
node_colors = {node: '#D3D3D3' for node in G.nodes}  # Nodos no visitados en gris claro
edge_colors = {edge: '#000000' for edge in G.edges}  # Aristas no procesadas en negro

# Definir la leyenda con colores consistentes
legend_elements = [
    mpatches.Patch(color='#D3D3D3', label='Pendiente'),         # Gris claro
    mpatches.Patch(color='#00BFFF', label='Explorado'),         # Azul claro
    mpatches.Patch(color='#FF6347', label='Nodo actual'),       # Rojo tomate
    mpatches.Patch(color='#228B22', label='Ruta confirmada')    # Verde bosque
]

# Función para construir la ruta hasta un nodo dado
def construir_ruta(nodo):
    ruta = []
    while nodo is not None:
        ruta.append(nodo)
        nodo = previous[nodo]
    return ruta[::-1]  # Invertir para mostrar de inicio a fin

# Función para dibujar el grafo en cada paso
def draw_graph(ax, G, pos, step):
    ax.clear()  # Limpiar el gráfico en cada actualización
    plt.subplots_adjust(top=0.85, left=0.1, right=0.9, bottom=0.2)

    # Dibujar nodos y aristas hasta el paso actual
    nx.draw(G, pos, with_labels=True, node_color=[node_colors[n] for n in G.nodes], node_size=600, ax=ax)
    nx.draw_networkx_edges(G, pos, edge_color=[edge_colors[e] for e in G.edges], width=1.5, ax=ax)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

    # Dibujar la leyenda con colores consistentes
    ax.legend(handles=legend_elements, loc='upper center', bbox_to_anchor=(0.5, -0.1), framealpha=0.8, fontsize='small', ncol=4)

# Función de actualización para cada paso de la animación
def update(frame):
    # Obtener el nodo actual y construir la ruta confirmada hasta él
    current_node = visited_order[frame % len(visited_order)]
    path_nodes = construir_ruta(current_node)

    # Actualizar colores de nodos y aristas para la ruta confirmada
    for i in range(len(path_nodes) - 1):
        node_colors[path_nodes[i]] = '#00BFFF'  # Azul para nodos explorados
        edge_colors[(path_nodes[i], path_nodes[i+1])] = '#228B22'  # Verde para ruta confirmada

    # Marcar el nodo actual en rojo
    node_colors[current_node] = '#FF6347'  # Rojo para el nodo actual

    # Resaltar nodo de inicio y nodo objetivo
    nx.draw_networkx_nodes(G, pos, nodelist=[start_node], node_color='#00FFFF', node_shape='p', node_size=900, ax=ax)  # Inicio en cian
    nx.draw_networkx_nodes(G, pos, nodelist=['g'], node_color='#FFFF00', node_shape='s', node_size=900, ax=ax)  # Objetivo en amarillo

    # Actualizar el título para mostrar el nodo y distancia actual
    step = (frame % len(visited_order)) + 1
    current_dist = distances[current_node]
    plt.title(f"Paso {step}: Procesando nodo '{current_node}' con distancia acumulada {current_dist}", fontsize=12)

    # Dibujar el grafo
    draw_graph(ax, G, pos, step)

# Crear la animación con efecto continuo
ani = FuncAnimation(fig, update, frames=len(visited_order) * 3, interval=500, repeat=True)

# Mostrar la animación con controles interactivos en el notebook
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib.animation import FuncAnimation, PillowWriter
from IPython.display import HTML
from google.colab import files
import heapq
import matplotlib.patches as mpatches

# Create the graph and add edges with weights
G = nx.Graph()
edges = [
    ('d', 'a', 6), ('d', 'c', 1), ('d', 'e', 2),
    ('a', 'e', 2), ('a', 'b', 1), ('a', 'f', 2),
    ('b', 'g', 6), ('b', 'c', 3), ('e', 'f', 3),
    ('f', 'g', 3)
]
G.add_weighted_edges_from(edges)

# Define positions for the nodes for a clearer layout
pos = {
    'd': (0, 0), 'a': (1, 1), 'c': (2, 0), 'e': (0, 2),
    'f': (1, 3), 'b': (3, 1), 'g': (2.5, 3)
}

# Initialize Dijkstra's algorithm
start_node = 'd'
distances = {node: float('inf') for node in G.nodes}
distances[start_node] = 0
previous = {node: None for node in G.nodes}
priority_queue = [(0, start_node)]
visited_order = []

# Run Dijkstra's algorithm and record visit order
while priority_queue:
    current_distance, current_node = heapq.heappop(priority_queue)
    if current_distance > distances[current_node]:
        continue
    visited_order.append(current_node)
    for neighbor, weight in G[current_node].items():
        distance = current_distance + weight['weight']
        if distance < distances[neighbor]:
            distances[neighbor] = distance
            previous[neighbor] = current_node
            heapq.heappush(priority_queue, (distance, neighbor))

# Prepare the animation
fig, ax = plt.subplots(figsize=(8, 6))
fig.patch.set_facecolor('#F5F5F5')  # Light background
plt.axis('off')  # Hide axes
edge_labels = {(u, v): d['weight'] for u, v, d in G.edges(data=True)}

# Initial colors for nodes and edges
node_colors = {node: '#D3D3D3' for node in G.nodes}  # Light gray for unvisited nodes
edge_colors = {edge: '#000000' for edge in G.edges}  # Black for unprocessed edges

# Define the legend with consistent colors
legend_elements = [
    mpatches.Patch(color='#D3D3D3', label='Pending'),
    mpatches.Patch(color='#00BFFF', label='Explored'),
    mpatches.Patch(color='#FF6347', label='Current Node'),
    mpatches.Patch(color='#228B22', label='Confirmed Path')
]

# Function to build the path to a given node
def build_path(node):
    path = []
    while node is not None:
        path.append(node)
        node = previous[node]
    return path[::-1]  # Reverse to show from start to finish

# Function to draw the graph at each step
def draw_graph(ax, G, pos, step):
    ax.clear()  # Clear the plot in each update
    plt.subplots_adjust(top=0.85, left=0.1, right=0.9, bottom=0.2)

    # Draw nodes and edges up to the current step
    nx.draw(G, pos, with_labels=True, node_color=[node_colors[n] for n in G.nodes], node_size=600, ax=ax)
    nx.draw_networkx_edges(G, pos, edge_color=[edge_colors[e] for e in G.edges], width=1.5, ax=ax)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

    # Draw the legend with consistent colors
    ax.legend(handles=legend_elements, loc='upper center', bbox_to_anchor=(0.5, -0.1), framealpha=0.8, fontsize='small', ncol=4)

# Update function for each step of the animation
def update(frame):
    # Get the current node and build the confirmed path up to it
    current_node = visited_order[frame % len(visited_order)]
    path_nodes = build_path(current_node)

    # Update node and edge colors for the confirmed path
    for i in range(len(path_nodes) - 1):
        node_colors[path_nodes[i]] = '#00BFFF'  # Blue for explored nodes
        edge_colors[(path_nodes[i], path_nodes[i+1])] = '#228B22'  # Green for confirmed path

    # Mark the current node in red
    node_colors[current_node] = '#FF6347'  # Red for the current node

    # Highlight the start and goal nodes
    nx.draw_networkx_nodes(G, pos, nodelist=[start_node], node_color='#00FFFF', node_shape='p', node_size=900, ax=ax)  # Start in cyan
    nx.draw_networkx_nodes(G, pos, nodelist=['g'], node_color='#FFFF00', node_shape='s', node_size=900, ax=ax)  # Goal in yellow

    # Update title to display current node and accumulated distance
    step = (frame % len(visited_order)) + 1
    current_dist = distances[current_node]
    plt.title(f"Step {step}: Processing node '{current_node}' with accumulated distance {current_dist}", fontsize=12)

    # Draw the graph
    draw_graph(ax, G, pos, step)

# Create the animation with a continuous effect
ani = FuncAnimation(fig, update, frames=len(visited_order) * 3, interval=500, repeat=True)

# Export the animation to MP4
mp4_path = "/content/dijkstra_animation_continuous.mp4"
ani.save(mp4_path, writer='ffmpeg', fps=2)
print("MP4 saved with continuous effect!")

# Export the animation to GIF
gif_path = "/content/dijkstra_animation_continuous.gif"
ani.save(gif_path, writer=PillowWriter(fps=2))
print("GIF saved with continuous effect!")

# Display the MP4 in the notebook
HTML(f'<video width="600" controls><source src="{mp4_path}" type="video/mp4"></video>')

# Download the MP4 and GIF files
files.download(mp4_path)
files.download(gif_path)
# Out:
# MP4 saved with continuous effect!
# GIF saved with continuous effect!

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import heapq
import matplotlib.patches as mpatches

# Create the graph and add edges with weights
G = nx.Graph()
edges = [
    ('d', 'a', 6), ('d', 'c', 1), ('d', 'e', 2),
    ('a', 'e', 2), ('a', 'b', 1), ('a', 'f', 2),
    ('b', 'g', 6), ('b', 'c', 3), ('e', 'f', 3),
    ('f', 'g', 3)
]
G.add_weighted_edges_from(edges)

# Define positions for the nodes for a clearer layout
pos = {
    'd': (0, 0), 'a': (1, 1), 'c': (2, 0), 'e': (0, 2),
    'f': (1, 3), 'b': (3, 1), 'g': (2.5, 3)
}

# Initialize Dijkstra's algorithm
start_node = 'd'
distances = {node: float('inf') for node in G.nodes}
distances[start_node] = 0
previous = {node: None for node in G.nodes}
priority_queue = [(0, start_node)]
visited_order = []

# Run Dijkstra's algorithm and record visit order
while priority_queue:
    current_distance, current_node = heapq.heappop(priority_queue)
    if current_distance > distances[current_node]:
        continue
    visited_order.append(current_node)
    for neighbor, weight in G[current_node].items():
        distance = current_distance + weight['weight']
        if distance < distances[neighbor]:
            distances[neighbor] = distance
            previous[neighbor] = current_node
            heapq.heappush(priority_queue, (distance, neighbor))

# Prepare the animation
fig, ax = plt.subplots(figsize=(8, 6))
fig.patch.set_facecolor('#F5F5F5')  # Light background
plt.axis('off')  # Hide axes
edge_labels = {(u, v): d['weight'] for u, v, d in G.edges(data=True)}

# Initial colors for nodes and edges
node_colors = {node: '#D3D3D3' for node in G.nodes}  # Light gray for unvisited nodes
edge_colors = {edge: '#000000' for edge in G.edges}  # Black for unprocessed edges

# Define the legend with consistent colors
legend_elements = [
    mpatches.Patch(color='#D3D3D3', label='Pendiente'),
    mpatches.Patch(color='#00BFFF', label='Explorado'),
    mpatches.Patch(color='#FF6347', label='Nodo actual'),
    mpatches.Patch(color='#228B22', label='Ruta confirmada')
]

# Function to build the path to a given node
def build_path(node):
    path = []
    while node is not None:
        path.append(node)
        node = previous[node]
    return path[::-1]  # Reverse to show from start to finish

# Function to draw the graph at each step
def draw_graph(ax, G, pos, step):
    ax.clear()  # Clear the plot in each update
    plt.subplots_adjust(top=0.85, left=0.1, right=0.9, bottom=0.2)

    # Draw nodes and edges up to the current step
    nx.draw(G, pos, with_labels=True, node_color=[node_colors[n] for n in G.nodes], node_size=600, ax=ax)
    nx.draw_networkx_edges(G, pos, edge_color=[edge_colors[e] for e in G.edges], width=1.5, ax=ax)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

    # Draw the legend with consistent colors
    ax.legend(handles=legend_elements, loc='upper center', bbox_to_anchor=(0.5, -0.1), framealpha=0.8, fontsize='small', ncol=4)

# Update function for each step of the animation
def update(frame):
    # Get the current node and build the confirmed path up to it
    current_node = visited_order[frame % len(visited_order)]
    path_nodes = build_path(current_node)

    # Update node and edge colors for the confirmed path
    for i in range(len(path_nodes) - 1):
        node_colors[path_nodes[i]] = '#00BFFF'  # Blue for explored nodes
        edge_colors[(path_nodes[i], path_nodes[i+1])] = '#228B22'  # Green for confirmed path

    # Mark the current node in red
    node_colors[current_node] = '#FF6347'  # Red for the current node

    # Highlight the start and goal nodes
    nx.draw_networkx_nodes(G, pos, nodelist=[start_node], node_color='#00FFFF', node_shape='p', node_size=900, ax=ax)  # Start in cyan
    nx.draw_networkx_nodes(G, pos, nodelist=['g'], node_color='#FFFF00', node_shape='s', node_size=900, ax=ax)  # Goal in yellow

    # Update title to display current node and accumulated distance
    step = (frame % len(visited_order)) + 1
    current_dist = distances[current_node]
    plt.title(f"Step {step}: Processing node '{current_node}' with accumulated distance {current_dist}", fontsize=12)

    # Draw the graph
    draw_graph(ax, G, pos, step)

# Create the animation with a continuous effect
ani = FuncAnimation(fig, update, frames=len(visited_order) * 3, interval=500, repeat=True)

# Display the animation with interactive controls in the notebook
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import heapq
import matplotlib.patches as mpatches

# Create the graph and add edges with weights
G = nx.Graph()
edges = [
    ('d', 'a', 6), ('d', 'c', 1), ('d', 'e', 2),
    ('a', 'e', 2), ('a', 'b', 1), ('a', 'f', 2),
    ('b', 'g', 6), ('b', 'c', 3), ('e', 'f', 3),
    ('f', 'g', 3)
]
G.add_weighted_edges_from(edges)

# Define positions for the nodes for a clearer layout
pos = {
    'd': (0, 0), 'a': (1, 1), 'c': (2, 0), 'e': (0, 2),
    'f': (1, 3), 'b': (3, 1), 'g': (2.5, 3)
}

# Initialize Dijkstra's algorithm
start_node = 'd'
distances = {node: float('inf') for node in G.nodes}
distances[start_node] = 0
previous = {node: None for node in G.nodes}
priority_queue = [(0, start_node)]
visited_order = []

# Run Dijkstra's algorithm and record visit order
while priority_queue:
    current_distance, current_node = heapq.heappop(priority_queue)
    if current_distance > distances[current_node]:
        continue
    visited_order.append(current_node)
    for neighbor, weight in G[current_node].items():
        distance = current_distance + weight['weight']
        if distance < distances[neighbor]:
            distances[neighbor] = distance
            previous[neighbor] = current_node
            heapq.heappush(priority_queue, (distance, neighbor))

# Prepare the animation
fig, ax = plt.subplots(figsize=(8, 6))
fig.patch.set_facecolor('#F5F5F5')  # Light background
plt.axis('off')  # Hide axes
edge_labels = {(u, v): d['weight'] for u, v, d in G.edges(data=True)}

# Initial colors for nodes and edges
node_colors = {node: '#D3D3D3' for node in G.nodes}  # Light gray for unvisited nodes
edge_colors = {edge: '#000000' for edge in G.edges}  # Black for unprocessed edges

# Define the legend with consistent colors
legend_elements = [
    mpatches.Patch(color='#D3D3D3', label='Pendiente'),
    mpatches.Patch(color='#00BFFF', label='Explorado'),
    mpatches.Patch(color='#FF6347', label='Nodo actual'),
    mpatches.Patch(color='#228B22', label='Ruta confirmada')
]

# Function to build the path to a given node
def build_path(node):
    path = []
    while node is not None:
        path.append(node)
        node = previous[node]
    return path[::-1]  # Reverse to show from start to finish

# Function to draw the graph at each step
def draw_graph(ax, G, pos, step):
    ax.clear()  # Clear the plot in each update
    plt.subplots_adjust(top=0.85, left=0.1, right=0.9, bottom=0.2)

    # Draw nodes and edges up to the current step
    nx.draw(G, pos, with_labels=True, node_color=[node_colors[n] for n in G.nodes], node_size=600, ax=ax)
    nx.draw_networkx_edges(G, pos, edge_color=[edge_colors[e] for e in G.edges], width=1.5, ax=ax)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

    # Draw the legend with consistent colors
    ax.legend(handles=legend_elements, loc='upper center', bbox_to_anchor=(0.5, -0.1), framealpha=0.8, fontsize='small', ncol=4)

# Update function for each step of the animation
def update(frame):
    # Get the current node and build the confirmed path up to it
    current_node = visited_order[frame % len(visited_order)]
    path_nodes = build_path(current_node)

    # Update node and edge colors for the confirmed path
    for i in range(len(path_nodes) - 1):
        node_colors[path_nodes[i]] = '#00BFFF'  # Blue for explored nodes
        edge_colors[(path_nodes[i], path_nodes[i+1])] = '#228B22'  # Green for confirmed path

    # Mark the current node in red
    node_colors[current_node] = '#FF6347'  # Red for the current node

    # Highlight the start and goal nodes
    nx.draw_networkx_nodes(G, pos, nodelist=[start_node], node_color='#00FFFF', node_shape='p', node_size=900, ax=ax)  # Start in cyan
    nx.draw_networkx_nodes(G, pos, nodelist=['g'], node_color='#FFFF00', node_shape='s', node_size=900, ax=ax)  # Goal in yellow

    # Update title to display current node and accumulated distance
    step = (frame % len(visited_order)) + 1
    current_dist = distances[current_node]
    plt.title(f"Step {step}: Processing node '{current_node}' with accumulated distance {current_dist}", fontsize=12)

    # Draw the graph
    draw_graph(ax, G, pos, step)

# Create the animation with a continuous effect
ani = FuncAnimation(fig, update, frames=len(visited_order) * 3, interval=500, repeat=True)

# Save the animation as an HTML file with controls
with open("dijkstra_animation_with_controls.html", "w") as f:
    f.write(ani.to_jshtml())

print("HTML file saved! You can download it and view it in a browser with interactive controls.")
# Out:
# HTML file saved! You can download it and view it in a browser with interactive controls.

# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Referencias sobre Algoritmo de Dijkstra</title>
    <style>
        /* Estilos básicos */
        body {
            font-family: 'Georgia', serif;
            line-height: 1.8;
            margin: 20px;
            padding: 20px;
            background-color: #f9f9f9;
        }
        h1, h2, h3 {
            color: #333;
            text-align: center;
        }
        h1 { font-size: 2.5em; }
        h2 { color: #0066cc; font-size: 2em; }
        p { font-size: 1.2em; margin-bottom: 15px; }
        .card {
            background-color: #ffffff;
            border-radius: 8px;
            box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1);
            padding: 20px;
            margin-bottom: 20px;
        }
        .divider {
            height: 2px;
            background-color: #e0e0e0;
            margin: 30px 0;
            border-radius: 4px;
        }
        /* Botones de enlaces */
        .button-link {
            display: inline-block;
            margin: 10px 5px;
            padding: 10px 20px;
            font-size: 1em;
            color: white;
            background-color: #0066cc;
            border: none;
            border-radius: 8px;
            text-align: center;
            text-decoration: none;
            transition: background-color 0.3s ease;
        }
        .button-link:hover {
            background-color: #005bb5;
        }
    </style>
</head>
<body>

    <h1>Referencias</h1>

    <div class="card">
        <h2>Discusión sobre el artículo de investigación</h2>
        <p>El artículo, titulado "<strong>Universal Optimality of Dijkstra via Beyond-Worst-Case Heaps</strong>", presenta un avance significativo en el estudio del algoritmo de Dijkstra, enfocándose en su rendimiento universalmente óptimo al usar una estructura de datos de heap con la propiedad de conjunto de trabajo ("working set property"). La investigación fue realizada por Bernhard Haeupler, Richard Hladík, Václav Rozhoň, Robert E. Tarjan y Jakub Tětek, y explora cómo el algoritmo de Dijkstra puede alcanzar un rendimiento más allá del peor caso, asegurando que sea lo más eficiente posible en cualquier topología de grafo.</p>

        <h3>Resumen del avance sobre el algoritmo de Dijkstra y su universalidad</h3>
        <p>Este estudio introduce el concepto de universalidad óptima en el contexto de los algoritmos secuenciales para grafos. La universalidad óptima se refiere a la capacidad de un algoritmo para adaptarse de manera óptima a cada estructura de grafo posible, manteniendo su eficiencia tanto en tiempo como en número de comparaciones necesarias para resolver problemas de caminos mínimos. Los autores demuestran que el algoritmo de Dijkstra, cuando se combina con un heap que posee la propiedad de conjunto de trabajo, es universalmente óptimo. Este avance implica que Dijkstra puede ejecutarse de manera óptima en cualquier grafo, independientemente de su topología, lo cual representa un avance en el análisis de algoritmos más allá del peor caso.</p>

        <h3>Comentario sobre la mejora en la estructura de datos del heap para optimalidad</h3>
        <p>Uno de los elementos clave de la investigación es el desarrollo de una nueva estructura de datos de heap que mejora los límites tradicionales de los heaps de Fibonacci. Esta estructura de heap con la propiedad de conjunto de trabajo permite que el costo de extracción de un elemento mínimo sea logarítmico en relación con la cantidad de elementos insertados después de él, en lugar de logarítmico en el total de elementos en el heap. Esta optimización facilita que el algoritmo de Dijkstra reduzca su tiempo de ejecución y número de comparaciones en topologías específicas de grafos, aprovechando la "localidad" en las operaciones del heap. Así, la propiedad de conjunto de trabajo permite que el algoritmo de Dijkstra sea óptimo en una amplia variedad de instancias.</p>

        <h3>Referencia completa al artículo para quienes quieran profundizar en el tema</h3>
        <p>Para aquellos interesados en profundizar en los detalles técnicos y matemáticos de esta mejora en el algoritmo de Dijkstra, se recomienda revisar el artículo completo:</p>
        <p><strong>Haeupler, B., Hladík, R., Rozhoň, V., Tarjan, R. E., & Tětek, J. (2024). Universal Optimality of Dijkstra via Beyond-Worst-Case Heaps. INSAIT, Sofia University & Princeton University. arXiv:2311.11793v3.</strong></p>
        <p>Este artículo ofrece una visión detallada del modelo de universalidad óptima, el análisis de complejidad, y las técnicas empleadas para construir el heap con la propiedad de conjunto de trabajo, así como aplicaciones potenciales en problemas de ordenamiento bajo información parcial y otras áreas de optimización de grafos.</p>

        <div class="divider"></div>

        <h2>Artículos Recomendados</h2>
        <p>A continuación se presentan enlaces a las fuentes originales del artículo técnico y un artículo en <em>Quanta Magazine</em> que explica el tema de forma más accesible:</p>
        <a href="https://arxiv.org/abs/2311.11793" target="_blank" class="button-link">Artículo en arXiv</a>
        <a href="https://www.quantamagazine.org/computer-scientists-establish-the-best-way-to-traverse-a-graph-20241025/" target="_blank" class="button-link">Artículo en Quanta Magazine</a>
    </div>
</body>
</html>
"""

# Mostrar el contenido HTML
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Referencias sobre Algoritmo de Dijkstra</title>
#     <style>
#         /* Estilos básicos */
#         body {
#             font-family: 'Georgia', serif;
#             line-height: 1.8;
#             margin: 20px;
#             padding: 20px;
#             background-color: #f9f9f9;
#         }
#         h1, h2, h3 {
#             color: #333;
#             text-align: center;
#         }
#         h1 { font-size: 2.5em; }
#         h2 { color: #0066cc; font-size: 2em; }
#         p { font-size: 1.2em; margin-bottom: 15px; }
#         .card {
#             background-color: #ffffff;
#             border-radius: 8px;
#             box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.1);
#             padding: 20px;
#             margin-bottom: 20px;
#         }
#         .divider {
#             height: 2px;
# ...

# %%
# Nombre del archivo notebook
nombre_archivo = 'BIG_DATA_CLASE_11_Dijkstra.ipynb'

# Instalar dependencias necesarias para la conversión a PDF
# !apt-get install -y texlive-xetex texlive-fonts-recommended texlive-generic-recommended > /dev/null 2>&1

# Convertir el notebook a formato Markdown
# !jupyter nbconvert --to markdown "{nombre_archivo}"

# Convertir el notebook a formato PDF
# !jupyter nbconvert --to pdf "{nombre_archivo}"
# Out:
# [NbConvertApp] WARNING | pattern 'BIG_DATA_CLASE_11_Dijkstra.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...

# %%
# Nombre del archivo notebook
nombre_archivo = 'BIG_DATA_CLASE_11_Dijkstra.ipynb'

# Instalar dependencias necesarias para la conversión a PDF
# !apt-get install -y texlive-xetex texlive-fonts-recommended texlive-generic-recommended > /dev/null 2>&1

# Convertir el notebook a formato Markdown
# !jupyter nbconvert --to markdown "{nombre_archivo}"
# Out:
# [NbConvertApp] WARNING | pattern 'BIG_DATA_CLASE_11_Dijkstra.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...

# %%
 # !pip install nbconvert

# %%
nbconvert --to markdown BIG_DATA_CLASE_11_Dijkstra.ipynb
# Out:
#   File "<ipython-input-24-bdcd063c245c>", line 1
#     nbconvert --to markdown BIG_DATA_CLASE_11_Dijkstra.ipynb
#                    ^
# SyntaxError: invalid syntax

# %%
from google.colab import files

# Download the HTML file
files.download("dijkstra_animation_with_controls.html")
